# %% [markdown]
# <a href="https://colab.research.google.com/github/Souptikbej/Pandas-Class/blob/main/Practice_Question_Answer_Theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Practice Questions**
# 1. What is a Series?
# 2. What is a DataFrame?
# 3. How do you create a Series?
# 4. How do you create a DataFrame?
# 5. Difference between df["Name"] and df[["Name"]]?
# 6. What does shape return?
# 7. What does info() return?
# 8. What does describe() return?
# 9. How do you add a new column?
# 10.  Why is DataFrame the most used Pandas structure?
# 1. What is CSV?
# 1. What is Excel?
# 1. How do you load a CSV file?
# 1. How do you load an Excel file?
# 1. How do you save a DataFrame as CSV?
# 1. Why use index=False?
# 1. What does usecols do?
# 1. What does nrows do?
# 1. What does sep do?
# 1. Which file format is more common in Data Science?
# 1. Difference between: df.head() and df.tail()
# 1. What does shape return?
# 1. Which function gives column names?
# 1. Why is info() important?
# 1. What does describe() return?
# 1. When would you use sample() instead of head()?
# 1. Difference between loc and iloc?
# 1. Difference between Series and DataFrame output?
# 1. Why use `value_counts()`?
# 1. What does `isin()` do?
# 1. What does `between()` do?
# 1. How do you filter multiple conditions?
# 1. Why must conditions be wrapped in parentheses?
# 1. Difference between: `fillna()` and `dropna()`
# 1. When should mean be used?
# 1. When should median be used?
# 1. How do you find duplicate rows?
# 1. How do you remove duplicates?
# 1. Why use `to_datetime()`?
# 1. Difference between: `astype()` and `to_numeric()`
# 1. Difference between `isnull()` and `notnull()`?
# 1. When should you use `mean` vs `median`?
# 1. Why is median better for salary?
# 1. What is `errors="coerce"` in `pd.to_numeric()`?
# 1. What is `errors="coerce"` in `pd.to_datetime()`?
# 1. Why should we standardize text values?
# 1. Why remove duplicates before analysis?
# 1. Why should data types be corrected before EDA?
# 1. What is the difference between NaN and NaT?
# 1. Difference between: `mean()` and `median()`
# 1. When is median preferred?
# 1. Difference between: `unique()` and `nunique()`
# 1. Difference between: `count()` and `value_counts()`
# 1. Difference between: `value_counts()` and `groupby().size()`
# 1. Why use as_index=False?
# 1. What does `agg()` do?
# 1. Can GroupBy use multiple columns?
# 1. Most common GroupBy functions?
# 1. What happens when columns don't match?
# 1. Difference between Merge and Concat?
# 1. Why use ignore_index=True?
# 1. Difference between: `pd.merge()` and `pd.concat()`
# 1. Default axis in concat?
# 1. How to concatenate columns?
# 1. Difference between: `inner` and `left` join?
# 1. Which join keeps all rows?
# 1. How to find unmatched records?
# 1. Can merge use multiple columns?
# 1. Most common join in industry?
# 1. What is the default join type?
# 1. Does `join()` use columns or indexes by default?
# 1. When would you prefer `join()` over `merge()`?
# 1. Can `join()` perform inner, left, right, and outer joins?
