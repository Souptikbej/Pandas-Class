# %% [markdown]
# <a href="https://colab.research.google.com/github/Souptikbej/Pandas-Class/blob/main/Practice4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Name":["Rahul","Priya","Rahul"," Amit ","Neha"],
    "Age":[25,np.nan,25,28,np.nan],
    "Salary":[50000,45000,50000,np.nan,55000]
})

print(df.info())
print("____________________________________")
print("Raw Data :\n",df)
print("____________________________________")

# Find missing values.
print("Missing Value :\n",df.isnull())
print("____________________________________")
# Count missing values.
print("Count Missing Value :\n",df.isnull().sum())
print("____________________________________")
# Fill Age with mean.
df["Age"].fillna(df["Age"].mean(),inplace=True)
print("Fill Age with mean :\n",df)
print("____________________________________")
# Fill Salary with median.
df['Salary'].fillna(df['Salary'].median(),inplace=True)
print("Fill Salary with median :\n",df)
print("____________________________________")
# Remove duplicates.
df.drop_duplicates(inplace=True)
print("Remove duplicates :\n",df)
print("____________________________________")
# Remove spaces from Name.
df['Name']=df['Name'].str.strip()
print("Remove spaces from Name :\n",df)
print("____________________________________")
# Convert Name to uppercase.
df['Name']=df['Name'].str.upper()
print("Convert Name to uppercase :\n",df)
print("____________________________________")
# Check data types.
print("Data types :\n",df.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     3 non-null      float64
#  2   Salary  4 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 252.0+ bytes
# None
# ____________________________________
# Raw Data :
#       Name   Age   Salary
# 0   Rahul  25.0  50000.0
# 1   Priya   NaN  45000.0
# 2   Rahul  25.0  50000.0
# 3   Amit   28.0      NaN
# 4    Neha   NaN  55000.0
# ____________________________________
# Missing Value :
#      Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False   False
# 3  False  False    True
# 4  False   True   False
# ____________________________________
# Count Missing Value :
#  Name      0
# Age       2
# Salary    1
# dtype: int64
# ____________________________________
# Fill Age with mean :
#       Name   Age   Salary
# 0   Rahul  25.0  50000.0
# 1   Priya  26.0  45000.0
# 2   Rahul  25.0  50000.0
# 3   Amit   28.0      NaN
# 4    Neha  26.0  55000.0
# ____________________________________
# Fill Salary with median :
#       Name   Age   Salary
# 0   Rahul  25.0  50000.0
# 1   Priya  26.0  45000.0
# 2   Rahul  25.0  50000.0
# 3   Amit   28.0  50000.0
# 4    Neha  26.0  55000.0
# ____________________________________
# Remove duplicates :
#       Name   Age   Salary
# 0   Rahul  25.0  50000.0
# 1   Priya  26.0  45000.0
# 3   Amit   28.0  50000.0
# 4    Neha  26.0  55000.0
# ____________________________________
# Remove spaces from Name :
#      Name   Age   Salary
# 0  Rahul  25.0  50000.0
# 1  Priya  26.0  45000.0
# 3   Amit  28.0  50000.0
# 4   Neha  26.0  55000.0
# ____________________________________
# Convert Name to uppercase :
#      Name   Age   Salary
# 0  RAHUL  25.0  50000.0
# 1  PRIYA  26.0  45000.0
# 3   AMIT  28.0  50000.0
# 4   NEHA  26.0  55000.0
# ____________________________________
# Data types :
#  Name       object
# Age       float64
# Salary    float64
# dtype: object
# /tmp/ipykernel_5131/3579632133.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace=True)
# /tmp/ipykernel_5131/3579632133.py:26: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].median(),inplace=True)

# %% [markdown]
# # Project 2

# %% [markdown]
# ## **Level 1: Basic Cleaning**
#
# **Missing Values**
#
# 1. Find missing values in the dataset.
# 1. Count missing values column-wise.
# 1. Find total missing values in the full dataset.
# 1. Find rows where Name is missing.
# 1. Fill missing Name with "Unknown".
# 1. Fill missing Age with the median age.
# 1. Fill missing Salary with the median salary.
# 1. Fill missing Gender with "Unknown".
# 1. Fill missing Join_Date with "Not Provided".
# 1. Replace empty string in Department with "Unknown".

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    "Customer_ID": [101, 102, 103, 104, 105, 105, 106, 107],
    "Name": [" Rahul ", "PRIYA", "amit", "Neha ", "rohan", "rohan", None, "Anjali"],
    "Age": [25, np.nan, 28, 27, 30, 30, -5, 26],
    "Gender": ["Male", "Female", "male", "FEMALE", "M", "M", "Female", None],
    "City": ["Kolkata", "kolkata ", "Delhi", "DELHI", "Mumbai", "Mumbai", "Pune", "pune"],
    "Salary": [50000, 45000, np.nan, 55000, 70000, 70000, 40000, "not available"],
    "Join_Date": ["2024-01-10", "10/02/2024", "2024-03-15", None, "2024-05-20", "2024-05-20", "wrong date", "2024-07-01"],
    "Department": ["IT", "HR", "it", "Finance", "IT Dept", "IT Dept", "HR", ""]
})

print(df.dtypes)

#Level 1: Basic Cleaning

#Missing Values

#Find missing values in the dataset.
print("Missing Values :\n",df.isna())
print("-------------------------------------")
#Count missing values column-wise.
print("Count missing values column-wise :\n",df.isna().sum())
print("-------------------------------------")
#Find total missing values in the full dataset.
print("Find total missing values in the full dataset : ",df.isna().sum().sum())
print("-------------------------------------")
#Find rows where Name is missing.
print("Find rows where Name is missing :\n",df[df['Name'].isna()])
print("-------------------------------------")
#Fill missing Name with "Unknown".
df['Name']=df['Name'].fillna("Unknown")
print("Fill missing Name with 'Unknown' :\n",df)
print("-------------------------------------")
#Fill missing Age with the median age.
df['Age']=df['Age'].fillna(df['Age'].median())
print("Fill missing Age with the median age :\n",df)
print("-------------------------------------")
#Fill missing Salary with the median salary.
df['Salary']=df['Salary'].replace("not available",np.nan)
df['Salary']=df['Salary'].fillna(df['Salary'].median())
print("Fill missing Salary with the median salary :\n",df)
print("-------------------------------------")
#Fill missing Gender with "Unknown".
df['Gender']=df['Gender'].fillna("Unknown")
print("Fill missing Gender with 'Unknown' :\n",df)
print("-------------------------------------")
#Fill missing Join_Date with "Not Provided".
df['Join_Date']=df['Join_Date'].fillna("Not Provided")
print("Fill missing Join_Date with 'Not Provided' :\n",df)
print("-------------------------------------")
#Replace empty string in Department with "Unknown".
df['Department']=df['Department'].replace("","Unknown")
print("Replace empty string in Department with 'Unknown' :\n",df)
print("-------------------------------------")
# Out:
# Customer_ID      int64
# Name            object
# Age            float64
# Gender          object
# City            object
# Salary          object
# Join_Date       object
# Department      object
# dtype: object
# Missing Values :
#     Customer_ID   Name    Age  Gender   City  Salary  Join_Date  Department
# 0        False  False  False   False  False   False      False       False
# 1        False  False   True   False  False   False      False       False
# 2        False  False  False   False  False    True      False       False
# 3        False  False  False   False  False   False       True       False
# 4        False  False  False   False  False   False      False       False
# 5        False  False  False   False  False   False      False       False
# 6        False   True  False   False  False   False      False       False
# 7        False  False  False    True  False   False      False       False
# -------------------------------------
# Count missing values column-wise :
#  Customer_ID    0
# Name           1
# Age            1
# Gender         1
# City           0
# Salary         1
# Join_Date      1
# Department     0
# dtype: int64
# -------------------------------------
# Find total missing values in the full dataset :  5
# -------------------------------------
# Find rows where Name is missing :
#     Customer_ID  Name  Age  Gender  City Salary   Join_Date Department
# 6          106  None -5.0  Female  Pune  40000  wrong date         HR
# -------------------------------------
# Fill missing Name with 'Unknown' :
#     Customer_ID     Name   Age  Gender      City         Salary   Join_Date  \
# 0          101   Rahul   25.0    Male   Kolkata          50000  2024-01-10
# 1          102    PRIYA   NaN  Female  kolkata           45000  10/02/2024
# 2          103     amit  28.0    male     Delhi            NaN  2024-03-15
# 3          104    Neha   27.0  FEMALE     DELHI          55000        None
# 4          105    rohan  30.0       M    Mumbai          70000  2024-05-20
# 5          105    rohan  30.0       M    Mumbai          70000  2024-05-20
# 6          106  Unknown  -5.0  Female      Pune          40000  wrong date
# 7          107   Anjali  26.0    None      pune  not available  2024-07-01
#
#   Department
# 0         IT
# 1         HR
# 2         it
# 3    Finance
# 4    IT Dept
# 5    IT Dept
# 6         HR
# 7
# -------------------------------------
# Fill missing Age with the median age :
#     Customer_ID     Name   Age  Gender      City         Salary   Join_Date  \
# 0          101   Rahul   25.0    Male   Kolkata          50000  2024-01-10
# 1          102    PRIYA  27.0  Female  kolkata           45000  10/02/2024
# 2          103     amit  28.0    male     Delhi            NaN  2024-03-15
# 3          104    Neha   27.0  FEMALE     DELHI          55000        None
# 4          105    rohan  30.0       M    Mumbai          70000  2024-05-20
# 5          105    rohan  30.0       M    Mumbai          70000  2024-05-20
# 6          106  Unknown  -5.0  Female      Pune          40000  wrong date
# 7          107   Anjali  26.0    None      pune  not available  2024-07-01
#
#   Department
# 0         IT
# 1         HR
# 2         it
# 3    Finance
# 4    IT Dept
# 5    IT Dept
# 6         HR
# 7
# -------------------------------------
# Fill missing Salary with the median salary :
#     Customer_ID     Name   Age  Gender      City   Salary   Join_Date  \
# 0          101   Rahul   25.0    Male   Kolkata  50000.0  2024-01-10
# 1          102    PRIYA  27.0  Female  kolkata   45000.0  10/02/2024
# 2          103     amit  28.0    male     Delhi  52500.0  2024-03-15
# 3          104    Neha   27.0  FEMALE     DELHI  55000.0        None
# 4          105    rohan  30.0       M    Mumbai  70000.0  2024-05-20
# 5          105    rohan  30.0       M    Mumbai  70000.0  2024-05-20
# 6          106  Unknown  -5.0  Female      Pune  40000.0  wrong date
# 7          107   Anjali  26.0    None      pune  52500.0  2024-07-01
#
#   Department
# 0         IT
# 1         HR
# 2         it
# 3    Finance
# 4    IT Dept
# 5    IT Dept
# 6         HR
# 7
# -------------------------------------
# Fill missing Gender with 'Unknown' :
#     Customer_ID     Name   Age   Gender      City   Salary   Join_Date  \
# 0          101   Rahul   25.0     Male   Kolkata  50000.0  2024-01-10
# 1          102    PRIYA  27.0   Female  kolkata   45000.0  10/02/2024
# 2          103     amit  28.0     male     Delhi  52500.0  2024-03-15
# 3          104    Neha   27.0   FEMALE     DELHI  55000.0        None
# 4          105    rohan  30.0        M    Mumbai  70000.0  2024-05-20
# 5          105    rohan  30.0        M    Mumbai  70000.0  2024-05-20
# 6          106  Unknown  -5.0   Female      Pune  40000.0  wrong date
# 7          107   Anjali  26.0  Unknown      pune  52500.0  2024-07-01
#
#   Department
# 0         IT
# 1         HR
# 2         it
# 3    Finance
# 4    IT Dept
# 5    IT Dept
# 6         HR
# 7
# -------------------------------------
# Fill missing Join_Date with 'Not Provided' :
#     Customer_ID     Name   Age   Gender      City   Salary     Join_Date  \
# 0          101   Rahul   25.0     Male   Kolkata  50000.0    2024-01-10
# 1          102    PRIYA  27.0   Female  kolkata   45000.0    10/02/2024
# 2          103     amit  28.0     male     Delhi  52500.0    2024-03-15
# 3          104    Neha   27.0   FEMALE     DELHI  55000.0  Not Provided
# 4          105    rohan  30.0        M    Mumbai  70000.0    2024-05-20
# 5          105    rohan  30.0        M    Mumbai  70000.0    2024-05-20
# 6          106  Unknown  -5.0   Female      Pune  40000.0    wrong date
# 7          107   Anjali  26.0  Unknown      pune  52500.0    2024-07-01
#
#   Department
# 0         IT
# 1         HR
# 2         it
# 3    Finance
# 4    IT Dept
# 5    IT Dept
# 6         HR
# 7
# -------------------------------------
# Replace empty string in Department with 'Unknown' :
#     Customer_ID     Name   Age   Gender      City   Salary     Join_Date  \
# 0          101   Rahul   25.0     Male   Kolkata  50000.0    2024-01-10
# 1          102    PRIYA  27.0   Female  kolkata   45000.0    10/02/2024
# 2          103     amit  28.0     male     Delhi  52500.0    2024-03-15
# 3          104    Neha   27.0   FEMALE     DELHI  55000.0  Not Provided
# 4          105    rohan  30.0        M    Mumbai  70000.0    2024-05-20
# 5          105    rohan  30.0        M    Mumbai  70000.0    2024-05-20
# 6          106  Unknown  -5.0   Female      Pune  40000.0    wrong date
# 7          107   Anjali  26.0  Unknown      pune  52500.0    2024-07-01
#
#   Department
# 0         IT
# 1         HR
# 2         it
# 3    Finance
# 4    IT Dept
# 5    IT Dept
# 6         HR
# 7    Unknown
# -------------------------------------
# /tmp/ipykernel_5131/3004580269.py:42: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Salary']=df['Salary'].replace("not available",np.nan)
